# %% [markdown]
# ### Persiapan
# Sebelum memulai semuanya, pastikan semua modul yang dibutuhkan terinstall dan drive sudah di-mount.

# %%
# Ini jangan lupa ya!
HAS_RUN_ONCE = False

# %%
# Di google colab hanya modul yang bukan bawaan
# !pip3 install python-dotenv

# Memeriksa apakah notebook dijalankan di google colab
import sys
from os import chdir, getcwd, path
IN_COLAB = 'google.colab' in sys.modules


if IN_COLAB:
    from google.colab import drive

    drive.mount("/content/gdrive")
    chdir("/content/gdrive/My Drive/sentiment-analysis")
# Out:
# ...
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %% [markdown]
# ### Melatih model
# Jalankan sel dibawah untuk melatih model dengan menjalankan `train.py`. Jangan lupa ganti _runtime_-nya ke GPU, ya! Supaya menghemat waktu!

# %%
if not IN_COLAB and not HAS_RUN_ONCE:
    chdir("..")
    HAS_RUN_ONCE = True

import train
# Out:
# Epoch 1/70

# %% [markdown]
# ### Menjalankan model
# Untuk menguji model, tinggal klik sel di bawah ini.

# %%
if IN_COLAB:
    import interactive
else:
    if not HAS_RUN_ONCE:
        chdir("..")
        HAS_RUN_ONCE = True
    import interactive
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-42199048133b> in <cell line: 1>()
#       1 if IN_COLAB:
# ----> 2     import interactive
#       3 else:
#       4     if not HAS_RUN_ONCE:
#       5         chdir("..")
#
# /content/gdrive/MyDrive/sentiment-analysis/interactive.py in <module>
#       3 # Mengambil input user dan memprediksinya
#       4 while True:
# ----> 5     sentence = str(input("Masukkan kalimat: "))
#       6     print(predict_sentiment(sentence))
#
# /usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     849                 "raw_input was called, but this frontend does not support input requests."
#     850             )
# --> 851         return self._input_request(str(prompt),
#     852             self._parent_ident,
#     853             self._parent_header,
#
# ...
